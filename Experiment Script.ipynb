# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt


package_metrics = pd.read_csv('PSOWE Dataset/DATASET/package_level_metrics_and_no_bugs.csv').iloc[0:30]
    # Assuming 'bug' is the target variable and all other relevant features are numeric
X = package_metrics.drop(['name', 'version', 'package_name', 'bug'], axis=1)  # Drop non-numeric and target columns
y = package_metrics['bug']

# Preprocess the data (e.g., standardization)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.1, random_state=42)
# Initialize and train the model
model = RandomForestRegressor(random_state=32)
model.fit(X, y)

# Make predictions on the test set
y_pred = model.predict(X_test)

# Calculate performance metrics
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
coefficient_of_dermination = r2_score(y_test, y_pred)
rmse = mse ** 0.5
print(f'R^2: {coefficient_of_dermination}')
# Out:
# R^2: 1.0

# %%
import os
import openai
import json
from openai import OpenAI

# api_key = 'INSERT_API_KEY'
api_key = os.getenv("OPENAI_API_KEY")
client = OpenAI(
    api_key=api_key,
    # api_key = os.getenv("OPENAI_API_KEY")
)
def get_completion(prompt, command = "", model="gpt-3.5-turbo", temperature = 0):
    if command != "" or command is not None:
        messages = [
            {"role": "system", "content": command},
            {"role": "user", "content": prompt}]
    else:
        messages = [
            {"role": "user", "content": prompt}]
    print(messages)
    response = client.chat.completions.create(
        model=model,
        messages=messages,
        temperature=temperature, # this is the degree of randomness of the model's output
    )
    return response.choices[0].message.content

# %%
experiment_df = pd.read_csv('experiment/experiment data.csv')
experiment_df_bugs = experiment_df['bug']
experiment_df = experiment_df.drop(['name', 'version', 'package_name', 'bug'], axis=1)
# experiment_df

# %%
results_df = pd.DataFrame(columns=["Actual", "OpenAI", "Model"])
prediction_df = model.predict(experiment_df)
results_df["Actual"] = experiment_df_bugs
results_df["Model"] = prediction_df
# results_df.at[0, 'OpenAI'] = 10
results_df
# Out:
#      Actual OpenAI  Model
# 0         0    NaN   0.00
# 1         0    NaN   0.09
# 2         0    NaN   0.87
# 3         0    NaN   2.85
# 4         0    NaN   0.24
# ..      ...    ...    ...
# 137       1    NaN   0.00
# 138       0    NaN   1.11
# 139       0    NaN   1.43
# 140       0    NaN   0.00
# 141       0    NaN   0.00
#
# [142 rows x 3 columns]

# %%
import json
import re
import numpy as np
import time
for index, row in experiment_df.iterrows():
    # ask open ai to predict and store it in the results df\
    response = get_completion(command=package_metrics.to_json() + "Use this data to train a model to predict the number of bugs. Use random forest regression",
                                  prompt="I want to predict the number of bugs based on these metrics. I don't want python code. Please give me a numerical response" + row.to_json())
    results_df.at[index, 'OpenAI'] = float(np.asarray(re.findall(r'\b\d+\b', response)))
    time.sleep(22) # rate limits
# Out:
# [{'role': 'system', 'content': '{"name":{"0":"ant","1":"ant","2":"ant","3":"ant","4":"ant","5":"ant","6":"ant","7":"ant","8":"ant","9":"ant","10":"ant","11":"ant","12":"ant","13":"ant","14":"ant","15":"ant","16":"ant","17":"ant","18":"ant","19":"ant","20":"ant","21":"ant","22":"ant","23":"ant","24":"ant","25":"ant","26":"ant","27":"ant","28":"ant","29":"ant"},"version":{"0":"1.7","1":"1.7","2":"1.7","3":"1.7","4":"1.7","5":"1.7","6":"1.7","7":"1.7","8":"1.7","9":"1.7","10":"1.7","11":"1.7","12":"1.7","13":"1.7","14":"1.7","15":"1.7","16":"1.7","17":"1.7","18":"1.7","19":"1.7","20":"1.7","21":"1.7","22":"1.7","23":"1.7","24":"1.7","25":"1.7","26":"1.7","27":"1.7","28":"1.7","29":"1.7"},"package_name":{"0":"org.apache.tools.ant.AntClassLoader","1":"org.apache.tools.ant.AntTypeDefinition","2":"org.apache.tools.ant.BuildEvent","3":"org.apache.tools.ant.BuildException","4":"org.apache.tools.ant.BuildListener","5":"org.apache.tools.ant.BuildLogger","6":"org.apache.tools.ant.ComponentHelper
# ...

# %%
results_df
# Out:
#      Index  Actual  OpenAI  Model
# 0        0       0       0   0.00
# 1        1       0       0   0.09
# 2        2       0       0   0.87
# 3        3       0       2   2.85
# 4        4       0       0   0.24
# ..     ...     ...     ...    ...
# 130    130       0       0   0.00
# 131    131       0       0   1.71
# 132    132       1       2   1.03
# 133    133       0       0   1.02
# 134    134       1       1   0.94
#
# [135 rows x 4 columns]

# %%
#  save to csv incase anything happens, it will be easy to start from here
# results_df.to_csv('experiment_results.csv')

results_df = pd.read_csv('experiment_results.csv')

# %%
openai_score = r2_score(results_df["Actual"], results_df["OpenAI"])
model_score = r2_score(results_df["Actual"], results_df["Model"])
print(f'OpenAI accuracy = {openai_score}')
print(f'Model accuracy = {model_score}')
# Out:
# OpenAI accuracy = 0.018691588785046842
# Model accuracy = -0.01635514018691575

# %%
openai_score = mean_absolute_error(results_df["Actual"], results_df["OpenAI"])
model_score = mean_absolute_error(results_df["Actual"], results_df["Model"])
print(f'OpenAI Mean Absolute Error = {openai_score}')
print(f'Model Mean Absolute Error = {model_score}')
# Out:
# OpenAI Mean Absolute Error = 0.5777777777777777
# Model Mean Absolute Error = 0.6148148148148148

# %%
openai_score_rmse = np.sqrt(mean_absolute_error(results_df["Actual"], results_df["OpenAI"]))
model_score_rmse = np.sqrt(mean_absolute_error(results_df["Actual"], results_df["Model"]))
print(f'OpenAI Root Mean Squared Error = {openai_score}')
print(f'Model Root Mean Squared Error = {model_score}')
# Out:
# OpenAI Root Mean Squared Error = 0.5777777777777777
# Model Root Mean Squared Error = 0.6148148148148148
